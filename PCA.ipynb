# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul2611/Unsupervised_Clustring_Learning/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('student_data.csv')

# %%
X = df[["Attendance","AssignmentScore","ExamScore"]]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.46474021, 0.31510553])
